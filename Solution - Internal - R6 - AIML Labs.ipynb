# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-rc2

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X = iris.data
y = iris.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.25)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
model = tf.keras.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
model.add(tf.keras.layers.Dense(3, input_shape=(4,), activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200)
# Out:
# Train on 112 samples, validate on 38 samples
# Epoch 1/200
# 112/112 [==============================] - 0s 3ms/sample - loss: 2.7486 - accuracy: 0.3304 - val_loss: 1.6369 - val_accuracy: 0.3421
# Epoch 2/200
# 112/112 [==============================] - 0s 222us/sample - loss: 1.6411 - accuracy: 0.3214 - val_loss: 1.2293 - val_accuracy: 0.0526
# Epoch 3/200
# 112/112 [==============================] - 0s 214us/sample - loss: 1.2954 - accuracy: 0.0625 - val_loss: 1.2086 - val_accuracy: 0.2105
# Epoch 4/200
# 112/112 [==============================] - 0s 227us/sample - loss: 1.2044 - accuracy: 0.1964 - val_loss: 1.2073 - val_accuracy: 0.1579
# Epoch 5/200
# 112/112 [==============================] - 0s 231us/sample - loss: 1.1705 - accuracy: 0.2232 - val_loss: 1.1561 - val_accuracy: 0.2105
# Epoch 6/200
# 112/112 [==============================] - 0s 214us/sample - loss: 1.1267 - accuracy: 0.2679 - val_loss: 1.1220 - val_accuracy: 0.2105
# Epoch 7/200
# 112/112 [==============================] - 0s 259us/sample - loss: 1.0929 - accuracy: 0.2500 - val_loss: 1.1021 - val_accuracy: 0.1579
# Epoch 8/200
# 112/112 [==============================] - 0s 214us/sample - loss: 1.0640 - accuracy: 0.2321 - val_loss: 1.0627 - val_accuracy: 0.1842
# Epoch 9/200
# 112/112 [==============================] - 0s 187us/sample - loss: 1.0337 - accuracy: 0.2679 - val_loss: 1.0071 - val_accuracy: 0.2632
# Epoch 10/200
# 112/112 [==============================] - 0s 211us/sample - loss: 1.0186 - accuracy: 0.2946 - val_loss: 1.0048 - val_accuracy: 0.1842
# Epoch 11/200
# 112/112 [==============================] - 0s 190us/sample - loss: 0.9817 - accuracy: 0.3304 - val_loss: 1.0044 - val_accuracy: 0.1842
# Epoch 12/200
# 112/112 [==============================] - 0s 182us/sample - loss: 0.9534 - accuracy: 0.3393 - val_loss: 0.9593 - val_accuracy: 0.1842
# Epoch 13/200
# 112/112 [==============================] - 0s 213us/sample - loss: 0.9304 - accuracy: 0.4018 - val_loss: 0.9516 - val_accuracy: 0.2105
# Epoch 14/200
# 112/112 [==============================] - 0s 198us/sample - loss: 0.9101 - accuracy: 0.4464 - val_loss: 0.9201 - val_accuracy: 0.3421
# Epoch 15/200
# 112/112 [==============================] - 0s 218us/sample - loss: 0.8990 - accuracy: 0.5536 - val_loss: 0.9434 - val_accuracy: 0.3421
# Epoch 16/200
# 112/112 [==============================] - 0s 184us/sample - loss: 0.8754 - accuracy: 0.5893 - val_loss: 0.8807 - val_accuracy: 0.4737
# Epoch 17/200
# 112/112 [==============================] - 0s 216us/sample - loss: 0.8525 - accuracy: 0.6161 - val_loss: 0.8690 - val_accuracy: 0.4474
# Epoch 18/200
# 112/112 [==============================] - 0s 175us/sample - loss: 0.8366 - accuracy: 0.6429 - val_loss: 0.8524 - val_accuracy: 0.5263
# Epoch 19/200
# 112/112 [==============================] - 0s 209us/sample - loss: 0.8288 - accuracy: 0.6250 - val_loss: 0.8386 - val_accuracy: 0.5526
# Epoch 20/200
# 112/112 [==============================] - 0s 187us/sample - loss: 0.8143 - accuracy: 0.6696 - val_loss: 0.8071 - val_accuracy: 0.5526
# Epoch 21/200
# 112/112 [==============================] - 0s 189us/sample - loss: 0.7962 - accuracy: 0.6607 - val_loss: 0.8003 - val_accuracy: 0.5526
# Epoch 22/200
# 112/112 [==============================] - 0s 189us/sample - loss: 0.7768 - accuracy: 0.6875 - val_loss: 0.8114 - val_accuracy: 0.6053
# Epoch 23/200
# 112/112 [==============================] - 0s 195us/sample - loss: 0.7631 - accuracy: 0.6607 - val_loss: 0.8058 - val_accuracy: 0.5789
# Epoch 24/200
# 112/112 [==============================] - 0s 177us/sample - loss: 0.7519 - accuracy: 0.6607 - val_loss: 0.7819 - val_accuracy: 0.6053
# Epoch 25/200
# 112/112 [==============================] - 0s 182us/sample - loss: 0.7395 - accuracy: 0.6875 - val_loss: 0.7790 - val_accuracy: 0.5789
# Epoch 26/200
# 112/112 [==============================] - 0s 180us/sample - loss: 0.7402 - accuracy: 0.6696 - val_loss: 0.7593 - val_accuracy: 0.6053
# Epoch 27/200
# 112/112 [==============================] - 0s 203us/sample - loss: 0.7225 - accuracy: 0.6786 - val_loss: 0.7309 - val_accuracy: 0.6053
# Epoch 28/200
# 112/112 [==============================] - 0s 196us/sample - loss: 0.7112 - accuracy: 0.6964 - val_loss: 0.7130 - val_accuracy: 0.5526
# Epoch 29/200
# 112/112 [==============================] - 0s 184us/sample - loss: 0.7037 - accuracy: 0.7411 - val_loss: 0.7460 - val_accuracy: 0.6053
# Epoch 30/200
# 112/112 [==============================] - 0s 207us/sample - loss: 0.6929 - accuracy: 0.6875 - val_loss: 0.7289 - val_accuracy: 0.5789
# Epoch 31/200
# 112/112 [==============================] - 0s 197us/sample - loss: 0.6817 - accuracy: 0.6875 - val_loss: 0.7056 - val_accuracy: 0.6579
# Epoch 32/200
# 112/112 [==============================] - 0s 188us/sample - loss: 0.6731 - accuracy: 0.6964 - val_loss: 0.6996 - val_accuracy: 0.6579
# Epoch 33/200
# 112/112 [==============================] - 0s 188us/sample - loss: 0.6674 - accuracy: 0.6964 - val_loss: 0.6809 - val_accuracy: 0.6053
# Epoch 34/200
# 112/112 [==============================] - 0s 192us/sample - loss: 0.6606 - accuracy: 0.7143 - val_loss: 0.7028 - val_accuracy: 0.6053
# Epoch 35/200
# 112/112 [==============================] - 0s 186us/sample - loss: 0.6566 - accuracy: 0.6875 - val_loss: 0.6755 - val_accuracy: 0.6579
# Epoch 36/200
# 112/112 [==============================] - 0s 190us/sample - loss: 0.6489 - accuracy: 0.6964 - val_loss: 0.6504 - val_accuracy: 0.6316
# Epoch 37/200
# 112/112 [==============================] - 0s 208us/sample - loss: 0.6432 - accuracy: 0.7232 - val_loss: 0.6697 - val_accuracy: 0.6579
# Epoch 38/200
# 112/112 [==============================] - 0s 192us/sample - loss: 0.6310 - accuracy: 0.6964 - val_loss: 0.6789 - val_accuracy: 0.6053
# Epoch 39/200
# 112/112 [==============================] - 0s 197us/sample - loss: 0.6262 - accuracy: 0.6964 - val_loss: 0.6598 - val_accuracy: 0.6579
# Epoch 40/200
# 112/112 [==============================] - 0s 181us/sample - loss: 0.6217 - accuracy: 0.7232 - val_loss: 0.6565 - val_accuracy: 0.6316
# Epoch 41/200
# 112/112 [==============================] - 0s 186us/sample - loss: 0.6198 - accuracy: 0.7054 - val_loss: 0.6722 - val_accuracy: 0.6053
# Epoch 42/200
# 112/112 [==============================] - 0s 205us/sample - loss: 0.6186 - accuracy: 0.6964 - val_loss: 0.6681 - val_accuracy: 0.6053
# Epoch 43/200
# 112/112 [==============================] - 0s 217us/sample - loss: 0.6049 - accuracy: 0.6964 - val_loss: 0.6491 - val_accuracy: 0.6316
# Epoch 44/200
# 112/112 [==============================] - 0s 206us/sample - loss: 0.6043 - accuracy: 0.7411 - val_loss: 0.6542 - val_accuracy: 0.6053
# Epoch 45/200
# 112/112 [==============================] - 0s 182us/sample - loss: 0.5969 - accuracy: 0.6786 - val_loss: 0.6320 - val_accuracy: 0.6842
# Epoch 46/200
# 112/112 [==============================] - 0s 185us/sample - loss: 0.5877 - accuracy: 0.6964 - val_loss: 0.6253 - val_accuracy: 0.6842
# Epoch 47/200
# 112/112 [==============================] - 0s 186us/sample - loss: 0.5852 - accuracy: 0.7054 - val_loss: 0.6171 - val_accuracy: 0.6842
# Epoch 48/200
# 112/112 [==============================] - 0s 185us/sample - loss: 0.5865 - accuracy: 0.7054 - val_loss: 0.6272 - val_accuracy: 0.6316
# Epoch 49/200
# 112/112 [==============================] - 0s 195us/sample - loss: 0.5768 - accuracy: 0.7054 - val_loss: 0.6289 - val_accuracy: 0.6053
# Epoch 50/200
# 112/112 [==============================] - 0s 191us/sample - loss: 0.5716 - accuracy: 0.7143 - val_loss: 0.6058 - val_accuracy: 0.6842
# Epoch 51/200
# 112/112 [==============================] - 0s 230us/sample - loss: 0.5672 - accuracy: 0.7143 - val_loss: 0.6127 - val_accuracy: 0.6316
# Epoch 52/200
# 112/112 [==============================] - 0s 202us/sample - loss: 0.5680 - accuracy: 0.7232 - val_loss: 0.6339 - val_accuracy: 0.5789
# Epoch 53/200
# 112/112 [==============================] - 0s 204us/sample - loss: 0.5613 - accuracy: 0.6964 - val_loss: 0.6142 - val_accuracy: 0.6316
# Epoch 54/200
# 112/112 [==============================] - 0s 204us/sample - loss: 0.5564 - accuracy: 0.7143 - val_loss: 0.5861 - val_accuracy: 0.6842
# Epoch 55/200
# 112/112 [==============================] - 0s 204us/sample - loss: 0.5542 - accuracy: 0.7411 - val_loss: 0.5868 - val_accuracy: 0.7105
# Epoch 56/200
# 112/112 [==============================] - 0s 202us/sample - loss: 0.5496 - accuracy: 0.7054 - val_loss: 0.5765 - val_accuracy: 0.7105
# Epoch 57/200
# 112/112 [==============================] - 0s 215us/sample - loss: 0.5536 - accuracy: 0.7500 - val_loss: 0.5723 - val_accuracy: 0.7105
# Epoch 58/200
# 112/112 [==============================] - 0s 206us/sample - loss: 0.5450 - accuracy: 0.7679 - val_loss: 0.5823 - val_accuracy: 0.7105
# Epoch 59/200
# 112/112 [==============================] - 0s 201us/sample - loss: 0.5382 - accuracy: 0.7321 - val_loss: 0.5840 - val_accuracy: 0.7105
# Epoch 60/200
# 112/112 [==============================] - 0s 199us/sample - loss: 0.5358 - accuracy: 0.7321 - val_loss: 0.5829 - val_accuracy: 0.6579
# Epoch 61/200
# 112/112 [==============================] - 0s 196us/sample - loss: 0.5348 - accuracy: 0.7143 - val_loss: 0.5666 - val_accuracy: 0.7105
# Epoch 62/200
# 112/112 [==============================] - 0s 210us/sample - loss: 0.5294 - accuracy: 0.7589 - val_loss: 0.5733 - val_accuracy: 0.7105
# Epoch 63/200
# 112/112 [==============================] - 0s 210us/sample - loss: 0.5279 - accuracy: 0.7411 - val_loss: 0.5806 - val_accuracy: 0.6316
# Epoch 64/200
# 112/112 [==============================] - 0s 212us/sample - loss: 0.5242 - accuracy: 0.7321 - val_loss: 0.5769 - val_accuracy: 0.6316
# Epoch 65/200
# 112/112 [==============================] - 0s 239us/sample - loss: 0.5213 - accuracy: 0.7232 - val_loss: 0.5659 - val_accuracy: 0.7105
# Epoch 66/200
# 112/112 [==============================] - 0s 194us/sample - loss: 0.5230 - accuracy: 0.7589 - val_loss: 0.5613 - val_accuracy: 0.7105
# Epoch 67/200
# 112/112 [==============================] - 0s 186us/sample - loss: 0.5172 - accuracy: 0.7500 - val_loss: 0.5779 - val_accuracy: 0.6316
# Epoch 68/200
# 112/112 [==============================] - 0s 209us/sample - loss: 0.5137 - accuracy: 0.7500 - val_loss: 0.5587 - val_accuracy: 0.7105
# Epoch 69/200
# 112/112 [==============================] - 0s 244us/sample - loss: 0.5115 - accuracy: 0.7232 - val_loss: 0.5522 - val_accuracy: 0.7105
# Epoch 70/200
# 112/112 [==============================] - 0s 200us/sample - loss: 0.5099 - accuracy: 0.7679 - val_loss: 0.5476 - val_accuracy: 0.7368
# Epoch 71/200
# 112/112 [==============================] - 0s 249us/sample - loss: 0.5073 - accuracy: 0.7500 - val_loss: 0.5345 - val_accuracy: 0.7105
# Epoch 72/200
# 112/112 [==============================] - 0s 196us/sample - loss: 0.5049 - accuracy: 0.8214 - val_loss: 0.5506 - val_accuracy: 0.7105
# Epoch 73/200
# 112/112 [==============================] - 0s 225us/sample - loss: 0.5009 - accuracy: 0.7768 - val_loss: 0.5570 - val_accuracy: 0.6579
# Epoch 74/200
# 112/112 [==============================] - 0s 217us/sample - loss: 0.5000 - accuracy: 0.7321 - val_loss: 0.5438 - val_accuracy: 0.7105
# Epoch 75/200
# 112/112 [==============================] - 0s 211us/sample - loss: 0.4990 - accuracy: 0.7589 - val_loss: 0.5535 - val_accuracy: 0.6579
# Epoch 76/200
# 112/112 [==============================] - 0s 182us/sample - loss: 0.4957 - accuracy: 0.7679 - val_loss: 0.5439 - val_accuracy: 0.7105
# Epoch 77/200
# 112/112 [==============================] - 0s 179us/sample - loss: 0.4923 - accuracy: 0.7768 - val_loss: 0.5318 - val_accuracy: 0.7368
# Epoch 78/200
# 112/112 [==============================] - 0s 195us/sample - loss: 0.4923 - accuracy: 0.7768 - val_loss: 0.5362 - val_accuracy: 0.7368
# Epoch 79/200
# 112/112 [==============================] - 0s 219us/sample - loss: 0.4900 - accuracy: 0.7589 - val_loss: 0.5247 - val_accuracy: 0.7368
# Epoch 80/200
# 112/112 [==============================] - 0s 183us/sample - loss: 0.4865 - accuracy: 0.8036 - val_loss: 0.5325 - val_accuracy: 0.7368
# Epoch 81/200
# 112/112 [==============================] - 0s 189us/sample - loss: 0.4863 - accuracy: 0.7857 - val_loss: 0.5286 - val_accuracy: 0.7368
# Epoch 82/200
# 112/112 [==============================] - 0s 236us/sample - loss: 0.4858 - accuracy: 0.7589 - val_loss: 0.5198 - val_accuracy: 0.7368
# Epoch 83/200
# 112/112 [==============================] - 0s 234us/sample - loss: 0.4819 - accuracy: 0.8125 - val_loss: 0.5339 - val_accuracy: 0.6842
# Epoch 84/200
# 112/112 [==============================] - 0s 207us/sample - loss: 0.4790 - accuracy: 0.7946 - val_loss: 0.5360 - val_accuracy: 0.6579
# Epoch 85/200
# 112/112 [==============================] - 0s 221us/sample - loss: 0.4806 - accuracy: 0.8036 - val_loss: 0.5599 - val_accuracy: 0.6053
# Epoch 86/200
# 112/112 [==============================] - 0s 194us/sample - loss: 0.4777 - accuracy: 0.7679 - val_loss: 0.5418 - val_accuracy: 0.6579
# Epoch 87/200
# 112/112 [==============================] - 0s 225us/sample - loss: 0.4759 - accuracy: 0.7946 - val_loss: 0.5175 - val_accuracy: 0.7368
# Epoch 88/200
# 112/112 [==============================] - 0s 220us/sample - loss: 0.4730 - accuracy: 0.8125 - val_loss: 0.5176 - val_accuracy: 0.7368
# Epoch 89/200
# 112/112 [==============================] - 0s 246us/sample - loss: 0.4771 - accuracy: 0.8125 - val_loss: 0.5103 - val_accuracy: 0.7368
# Epoch 90/200
# 112/112 [==============================] - 0s 233us/sample - loss: 0.4702 - accuracy: 0.7946 - val_loss: 0.5094 - val_accuracy: 0.7368
# Epoch 91/200
# 112/112 [==============================] - 0s 218us/sample - loss: 0.4679 - accuracy: 0.8214 - val_loss: 0.5176 - val_accuracy: 0.7368
# Epoch 92/200
# 112/112 [==============================] - 0s 178us/sample - loss: 0.4684 - accuracy: 0.7857 - val_loss: 0.5150 - val_accuracy: 0.7368
# Epoch 93/200
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4642 - accuracy: 0.8304 - val_loss: 0.5125 - val_accuracy: 0.7368
# Epoch 94/200
# 112/112 [==============================] - 0s 217us/sample - loss: 0.4610 - accuracy: 0.8214 - val_loss: 0.5121 - val_accuracy: 0.7368
# Epoch 95/200
# 112/112 [==============================] - 0s 211us/sample - loss: 0.4634 - accuracy: 0.8036 - val_loss: 0.4863 - val_accuracy: 0.8158
# Epoch 96/200
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4609 - accuracy: 0.8661 - val_loss: 0.5071 - val_accuracy: 0.7368
# Epoch 97/200
# 112/112 [==============================] - 0s 200us/sample - loss: 0.4590 - accuracy: 0.8214 - val_loss: 0.4971 - val_accuracy: 0.7632
# Epoch 98/200
# 112/112 [==============================] - 0s 207us/sample - loss: 0.4558 - accuracy: 0.8393 - val_loss: 0.5111 - val_accuracy: 0.7105
# Epoch 99/200
# 112/112 [==============================] - 0s 203us/sample - loss: 0.4543 - accuracy: 0.8482 - val_loss: 0.5008 - val_accuracy: 0.7632
# Epoch 100/200
# 112/112 [==============================] - 0s 224us/sample - loss: 0.4527 - accuracy: 0.8214 - val_loss: 0.5165 - val_accuracy: 0.6842
# Epoch 101/200
# 112/112 [==============================] - 0s 205us/sample - loss: 0.4552 - accuracy: 0.8304 - val_loss: 0.5117 - val_accuracy: 0.7105
# Epoch 102/200
# 112/112 [==============================] - 0s 217us/sample - loss: 0.4500 - accuracy: 0.8304 - val_loss: 0.5168 - val_accuracy: 0.6579
# Epoch 103/200
# 112/112 [==============================] - 0s 208us/sample - loss: 0.4489 - accuracy: 0.8304 - val_loss: 0.5058 - val_accuracy: 0.7105
# Epoch 104/200
# 112/112 [==============================] - 0s 213us/sample - loss: 0.4485 - accuracy: 0.8304 - val_loss: 0.4936 - val_accuracy: 0.7632
# Epoch 105/200
# 112/112 [==============================] - 0s 260us/sample - loss: 0.4462 - accuracy: 0.8482 - val_loss: 0.4914 - val_accuracy: 0.7632
# Epoch 106/200
# 112/112 [==============================] - 0s 226us/sample - loss: 0.4436 - accuracy: 0.8482 - val_loss: 0.4979 - val_accuracy: 0.7632
# Epoch 107/200
# 112/112 [==============================] - 0s 230us/sample - loss: 0.4468 - accuracy: 0.8393 - val_loss: 0.5302 - val_accuracy: 0.6053
# Epoch 108/200
# 112/112 [==============================] - 0s 218us/sample - loss: 0.4441 - accuracy: 0.8036 - val_loss: 0.5054 - val_accuracy: 0.6842
# Epoch 109/200
# 112/112 [==============================] - 0s 196us/sample - loss: 0.4413 - accuracy: 0.8482 - val_loss: 0.5057 - val_accuracy: 0.6842
# Epoch 110/200
# 112/112 [==============================] - 0s 215us/sample - loss: 0.4442 - accuracy: 0.8304 - val_loss: 0.5218 - val_accuracy: 0.6579
# Epoch 111/200
# 112/112 [==============================] - 0s 193us/sample - loss: 0.4402 - accuracy: 0.8214 - val_loss: 0.5022 - val_accuracy: 0.6842
# Epoch 112/200
# 112/112 [==============================] - 0s 222us/sample - loss: 0.4364 - accuracy: 0.8571 - val_loss: 0.4838 - val_accuracy: 0.7632
# Epoch 113/200
# 112/112 [==============================] - 0s 228us/sample - loss: 0.4361 - accuracy: 0.8482 - val_loss: 0.4684 - val_accuracy: 0.8421
# Epoch 114/200
# 112/112 [==============================] - 0s 207us/sample - loss: 0.4381 - accuracy: 0.8393 - val_loss: 0.4622 - val_accuracy: 0.8684
# Epoch 115/200
# 112/112 [==============================] - 0s 226us/sample - loss: 0.4359 - accuracy: 0.8661 - val_loss: 0.4892 - val_accuracy: 0.7632
# Epoch 116/200
# 112/112 [==============================] - 0s 226us/sample - loss: 0.4318 - accuracy: 0.8661 - val_loss: 0.4973 - val_accuracy: 0.7105
# Epoch 117/200
# 112/112 [==============================] - 0s 237us/sample - loss: 0.4304 - accuracy: 0.8661 - val_loss: 0.4815 - val_accuracy: 0.7632
# Epoch 118/200
# 112/112 [==============================] - 0s 229us/sample - loss: 0.4303 - accuracy: 0.8661 - val_loss: 0.4724 - val_accuracy: 0.7632
# Epoch 119/200
# 112/112 [==============================] - 0s 326us/sample - loss: 0.4278 - accuracy: 0.8571 - val_loss: 0.4767 - val_accuracy: 0.7632
# Epoch 120/200
# 112/112 [==============================] - 0s 429us/sample - loss: 0.4283 - accuracy: 0.8482 - val_loss: 0.4858 - val_accuracy: 0.7368
# Epoch 121/200
# 112/112 [==============================] - 0s 388us/sample - loss: 0.4274 - accuracy: 0.8661 - val_loss: 0.4722 - val_accuracy: 0.7632
# Epoch 122/200
# 112/112 [==============================] - 0s 314us/sample - loss: 0.4275 - accuracy: 0.8839 - val_loss: 0.4755 - val_accuracy: 0.7632
# Epoch 123/200
# 112/112 [==============================] - 0s 321us/sample - loss: 0.4281 - accuracy: 0.8571 - val_loss: 0.4835 - val_accuracy: 0.7368
# Epoch 124/200
# 112/112 [==============================] - 0s 330us/sample - loss: 0.4294 - accuracy: 0.8393 - val_loss: 0.4689 - val_accuracy: 0.7632
# Epoch 125/200
# 112/112 [==============================] - 0s 260us/sample - loss: 0.4237 - accuracy: 0.8750 - val_loss: 0.4586 - val_accuracy: 0.8421
# Epoch 126/200
# 112/112 [==============================] - 0s 220us/sample - loss: 0.4224 - accuracy: 0.8750 - val_loss: 0.4734 - val_accuracy: 0.7632
# Epoch 127/200
# 112/112 [==============================] - 0s 238us/sample - loss: 0.4186 - accuracy: 0.8661 - val_loss: 0.4645 - val_accuracy: 0.7895
# Epoch 128/200
# 112/112 [==============================] - 0s 248us/sample - loss: 0.4193 - accuracy: 0.8661 - val_loss: 0.4914 - val_accuracy: 0.7105
# Epoch 129/200
# 112/112 [==============================] - 0s 220us/sample - loss: 0.4206 - accuracy: 0.8661 - val_loss: 0.4858 - val_accuracy: 0.7368
# Epoch 130/200
# 112/112 [==============================] - 0s 223us/sample - loss: 0.4207 - accuracy: 0.8661 - val_loss: 0.4856 - val_accuracy: 0.7368
# Epoch 131/200
# 112/112 [==============================] - 0s 225us/sample - loss: 0.4159 - accuracy: 0.8571 - val_loss: 0.4726 - val_accuracy: 0.7632
# Epoch 132/200
# 112/112 [==============================] - 0s 213us/sample - loss: 0.4143 - accuracy: 0.8750 - val_loss: 0.4686 - val_accuracy: 0.7632
# Epoch 133/200
# 112/112 [==============================] - 0s 232us/sample - loss: 0.4128 - accuracy: 0.8750 - val_loss: 0.4772 - val_accuracy: 0.7368
# Epoch 134/200
# 112/112 [==============================] - 0s 215us/sample - loss: 0.4131 - accuracy: 0.8750 - val_loss: 0.4701 - val_accuracy: 0.7632
# Epoch 135/200
# 112/112 [==============================] - 0s 249us/sample - loss: 0.4127 - accuracy: 0.8661 - val_loss: 0.4701 - val_accuracy: 0.7632
# Epoch 136/200
# 112/112 [==============================] - 0s 290us/sample - loss: 0.4125 - accuracy: 0.8750 - val_loss: 0.4669 - val_accuracy: 0.7632
# Epoch 137/200
# 112/112 [==============================] - 0s 246us/sample - loss: 0.4098 - accuracy: 0.8750 - val_loss: 0.4668 - val_accuracy: 0.7632
# Epoch 138/200
# 112/112 [==============================] - 0s 226us/sample - loss: 0.4079 - accuracy: 0.8839 - val_loss: 0.4642 - val_accuracy: 0.7632
# Epoch 139/200
# 112/112 [==============================] - 0s 288us/sample - loss: 0.4076 - accuracy: 0.8929 - val_loss: 0.4741 - val_accuracy: 0.7368
# Epoch 140/200
# 112/112 [==============================] - 0s 231us/sample - loss: 0.4081 - accuracy: 0.8750 - val_loss: 0.4668 - val_accuracy: 0.7632
# Epoch 141/200
# 112/112 [==============================] - 0s 221us/sample - loss: 0.4070 - accuracy: 0.8661 - val_loss: 0.4577 - val_accuracy: 0.7632
# Epoch 142/200
# 112/112 [==============================] - 0s 213us/sample - loss: 0.4038 - accuracy: 0.8839 - val_loss: 0.4580 - val_accuracy: 0.7632
# Epoch 143/200
# 112/112 [==============================] - 0s 227us/sample - loss: 0.4068 - accuracy: 0.8839 - val_loss: 0.4604 - val_accuracy: 0.7632
# Epoch 144/200
# 112/112 [==============================] - 0s 218us/sample - loss: 0.4061 - accuracy: 0.8661 - val_loss: 0.4474 - val_accuracy: 0.8421
# Epoch 145/200
# 112/112 [==============================] - 0s 232us/sample - loss: 0.4021 - accuracy: 0.8929 - val_loss: 0.4411 - val_accuracy: 0.8684
# Epoch 146/200
# 112/112 [==============================] - 0s 239us/sample - loss: 0.4025 - accuracy: 0.8929 - val_loss: 0.4365 - val_accuracy: 0.8684
# Epoch 147/200
# 112/112 [==============================] - 0s 263us/sample - loss: 0.4012 - accuracy: 0.8929 - val_loss: 0.4519 - val_accuracy: 0.7895
# Epoch 148/200
# 112/112 [==============================] - 0s 266us/sample - loss: 0.3984 - accuracy: 0.8929 - val_loss: 0.4491 - val_accuracy: 0.8158
# Epoch 149/200
# 112/112 [==============================] - 0s 225us/sample - loss: 0.4002 - accuracy: 0.8750 - val_loss: 0.4391 - val_accuracy: 0.8684
# Epoch 150/200
# 112/112 [==============================] - 0s 334us/sample - loss: 0.3974 - accuracy: 0.8929 - val_loss: 0.4446 - val_accuracy: 0.8158
# Epoch 151/200
# 112/112 [==============================] - 0s 260us/sample - loss: 0.3987 - accuracy: 0.9018 - val_loss: 0.4466 - val_accuracy: 0.8158
# Epoch 152/200
# 112/112 [==============================] - 0s 241us/sample - loss: 0.3960 - accuracy: 0.8839 - val_loss: 0.4387 - val_accuracy: 0.8684
# Epoch 153/200
# 112/112 [==============================] - 0s 221us/sample - loss: 0.3974 - accuracy: 0.8839 - val_loss: 0.4360 - val_accuracy: 0.8684
# Epoch 154/200
# 112/112 [==============================] - 0s 219us/sample - loss: 0.3940 - accuracy: 0.9018 - val_loss: 0.4426 - val_accuracy: 0.8158
# Epoch 155/200
# 112/112 [==============================] - 0s 227us/sample - loss: 0.3947 - accuracy: 0.9107 - val_loss: 0.4499 - val_accuracy: 0.7895
# Epoch 156/200
# 112/112 [==============================] - 0s 223us/sample - loss: 0.3925 - accuracy: 0.9107 - val_loss: 0.4591 - val_accuracy: 0.7368
# Epoch 157/200
# 112/112 [==============================] - 0s 242us/sample - loss: 0.3917 - accuracy: 0.8929 - val_loss: 0.4462 - val_accuracy: 0.7895
# Epoch 158/200
# 112/112 [==============================] - 0s 226us/sample - loss: 0.3906 - accuracy: 0.9018 - val_loss: 0.4360 - val_accuracy: 0.8684
# Epoch 159/200
# 112/112 [==============================] - 0s 255us/sample - loss: 0.3900 - accuracy: 0.9196 - val_loss: 0.4418 - val_accuracy: 0.8158
# Epoch 160/200
# 112/112 [==============================] - 0s 220us/sample - loss: 0.3904 - accuracy: 0.8839 - val_loss: 0.4370 - val_accuracy: 0.8421
# Epoch 161/200
# 112/112 [==============================] - 0s 227us/sample - loss: 0.3895 - accuracy: 0.9018 - val_loss: 0.4508 - val_accuracy: 0.7632
# Epoch 162/200
# 112/112 [==============================] - 0s 227us/sample - loss: 0.3870 - accuracy: 0.9018 - val_loss: 0.4436 - val_accuracy: 0.7895
# Epoch 163/200
# 112/112 [==============================] - 0s 231us/sample - loss: 0.3862 - accuracy: 0.9107 - val_loss: 0.4429 - val_accuracy: 0.7895
# Epoch 164/200
# 112/112 [==============================] - 0s 216us/sample - loss: 0.3876 - accuracy: 0.9196 - val_loss: 0.4543 - val_accuracy: 0.7368
# Epoch 165/200
# 112/112 [==============================] - 0s 256us/sample - loss: 0.3864 - accuracy: 0.8750 - val_loss: 0.4298 - val_accuracy: 0.8684
# Epoch 166/200
# 112/112 [==============================] - 0s 214us/sample - loss: 0.3862 - accuracy: 0.9107 - val_loss: 0.4434 - val_accuracy: 0.7895
# Epoch 167/200
# 112/112 [==============================] - 0s 269us/sample - loss: 0.3846 - accuracy: 0.8839 - val_loss: 0.4260 - val_accuracy: 0.8684
# Epoch 168/200
# 112/112 [==============================] - 0s 248us/sample - loss: 0.3835 - accuracy: 0.9196 - val_loss: 0.4324 - val_accuracy: 0.8684
# Epoch 169/200
# 112/112 [==============================] - 0s 281us/sample - loss: 0.3825 - accuracy: 0.9196 - val_loss: 0.4265 - val_accuracy: 0.8684
# Epoch 170/200
# 112/112 [==============================] - 0s 238us/sample - loss: 0.3824 - accuracy: 0.9107 - val_loss: 0.4494 - val_accuracy: 0.7368
# Epoch 171/200
# 112/112 [==============================] - 0s 241us/sample - loss: 0.3819 - accuracy: 0.8839 - val_loss: 0.4372 - val_accuracy: 0.7895
# Epoch 172/200
# 112/112 [==============================] - 0s 246us/sample - loss: 0.3825 - accuracy: 0.9196 - val_loss: 0.4344 - val_accuracy: 0.8158
# Epoch 173/200
# 112/112 [==============================] - 0s 224us/sample - loss: 0.3817 - accuracy: 0.9196 - val_loss: 0.4313 - val_accuracy: 0.8684
# Epoch 174/200
# 112/112 [==============================] - 0s 231us/sample - loss: 0.3782 - accuracy: 0.9196 - val_loss: 0.4369 - val_accuracy: 0.7895
# Epoch 175/200
# 112/112 [==============================] - 0s 228us/sample - loss: 0.3787 - accuracy: 0.9107 - val_loss: 0.4281 - val_accuracy: 0.8684
# Epoch 176/200
# 112/112 [==============================] - 0s 280us/sample - loss: 0.3803 - accuracy: 0.9196 - val_loss: 0.4235 - val_accuracy: 0.8684
# Epoch 177/200
# 112/112 [==============================] - 0s 234us/sample - loss: 0.3775 - accuracy: 0.9286 - val_loss: 0.4305 - val_accuracy: 0.8158
# Epoch 178/200
# 112/112 [==============================] - 0s 232us/sample - loss: 0.3764 - accuracy: 0.9196 - val_loss: 0.4330 - val_accuracy: 0.8158
# Epoch 179/200
# 112/112 [==============================] - 0s 244us/sample - loss: 0.3795 - accuracy: 0.9107 - val_loss: 0.4238 - val_accuracy: 0.8684
# Epoch 180/200
# 112/112 [==============================] - 0s 244us/sample - loss: 0.3746 - accuracy: 0.9286 - val_loss: 0.4168 - val_accuracy: 0.8684
# Epoch 181/200
# 112/112 [==============================] - 0s 220us/sample - loss: 0.3772 - accuracy: 0.9196 - val_loss: 0.4453 - val_accuracy: 0.7368
# Epoch 182/200
# 112/112 [==============================] - 0s 274us/sample - loss: 0.3732 - accuracy: 0.9018 - val_loss: 0.4366 - val_accuracy: 0.7895
# Epoch 183/200
# 112/112 [==============================] - 0s 244us/sample - loss: 0.3726 - accuracy: 0.9018 - val_loss: 0.4212 - val_accuracy: 0.8684
# Epoch 184/200
# 112/112 [==============================] - 0s 228us/sample - loss: 0.3710 - accuracy: 0.9286 - val_loss: 0.4219 - val_accuracy: 0.8684
# Epoch 185/200
# 112/112 [==============================] - 0s 250us/sample - loss: 0.3734 - accuracy: 0.9196 - val_loss: 0.4137 - val_accuracy: 0.8684
# Epoch 186/200
# 112/112 [==============================] - 0s 221us/sample - loss: 0.3707 - accuracy: 0.9286 - val_loss: 0.4133 - val_accuracy: 0.8684
# Epoch 187/200
# 112/112 [==============================] - 0s 223us/sample - loss: 0.3704 - accuracy: 0.9107 - val_loss: 0.4201 - val_accuracy: 0.8684
# Epoch 188/200
# 112/112 [==============================] - 0s 240us/sample - loss: 0.3686 - accuracy: 0.9286 - val_loss: 0.4167 - val_accuracy: 0.8684
# Epoch 189/200
# 112/112 [==============================] - 0s 298us/sample - loss: 0.3686 - accuracy: 0.9107 - val_loss: 0.4135 - val_accuracy: 0.8684
# Epoch 190/200
# 112/112 [==============================] - 0s 240us/sample - loss: 0.3674 - accuracy: 0.9375 - val_loss: 0.4220 - val_accuracy: 0.8684
# Epoch 191/200
# 112/112 [==============================] - 0s 240us/sample - loss: 0.3726 - accuracy: 0.9196 - val_loss: 0.4255 - val_accuracy: 0.8421
# Epoch 192/200
# 112/112 [==============================] - 0s 288us/sample - loss: 0.3678 - accuracy: 0.9107 - val_loss: 0.4220 - val_accuracy: 0.8684
# Epoch 193/200
# 112/112 [==============================] - 0s 195us/sample - loss: 0.3669 - accuracy: 0.9286 - val_loss: 0.4290 - val_accuracy: 0.7895
# Epoch 194/200
# 112/112 [==============================] - 0s 216us/sample - loss: 0.3649 - accuracy: 0.9107 - val_loss: 0.4261 - val_accuracy: 0.8158
# Epoch 195/200
# 112/112 [==============================] - 0s 213us/sample - loss: 0.3642 - accuracy: 0.9286 - val_loss: 0.4253 - val_accuracy: 0.8158
# Epoch 196/200
# 112/112 [==============================] - 0s 239us/sample - loss: 0.3632 - accuracy: 0.9196 - val_loss: 0.4221 - val_accuracy: 0.8421
# Epoch 197/200
# 112/112 [==============================] - 0s 202us/sample - loss: 0.3647 - accuracy: 0.9196 - val_loss: 0.4118 - val_accuracy: 0.8684
# Epoch 198/200
# 112/112 [==============================] - 0s 197us/sample - loss: 0.3630 - accuracy: 0.9286 - val_loss: 0.4047 - val_accuracy: 0.8947
# Epoch 199/200
# 112/112 [==============================] - 0s 201us/sample - loss: 0.3639 - accuracy: 0.9286 - val_loss: 0.4157 - val_accuracy: 0.8684
# Epoch 200/200
# 112/112 [==============================] - 0s 199us/sample - loss: 0.3614 - accuracy: 0.9196 - val_loss: 0.4095 - val_accuracy: 0.8684

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
model.predict(X_test[0:1])
# Out:
# array([[0.9711067 , 0.02711953, 0.00177377]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
y_test[0:1]
# Out:
# array([[1., 0., 0.]], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-rc2

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0988e498-843c-4420-92b1-aecc02cd3ac9" name="files[]" multiple disabled />
#      <output id="result-0988e498-843c-4420-92b1-aecc02cd3ac9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices.csv

# %%
import pandas as pd
df = pd.read_csv('prices.csv')

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
df = df.drop(['date', 'symbol'], axis=1)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
df = df[:1000]

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
X = df.drop('volume', axis=1)
y = df['volume']/1000000

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
import numpy as np
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X = tf.math.l2_normalize(X)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
W = tf.zeros(shape=(4, 1))
b = tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function
def prediction(features, W, b):
    y_pred = tf.add(tf.matmul(features, W), b)
    return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def loss(y_actual, y_predicted):
    diff = y_actual - y_predicted
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
    # Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        t.watch([w,b])
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    
    return w, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):    
    W, b = train(X, y, W, b)
    print('Current Training Loss on iteration', i, loss(y, prediction(X, W, b)).numpy())
# Out:
# Current Training Loss on iteration 0 236.16759
# Current Training Loss on iteration 1 235.09299
# Current Training Loss on iteration 2 234.06102
# Current Training Loss on iteration 3 233.06998
# Current Training Loss on iteration 4 232.11781
# Current Training Loss on iteration 5 231.20381
# Current Training Loss on iteration 6 230.32585
# Current Training Loss on iteration 7 229.48265
# Current Training Loss on iteration 8 228.67297
# Current Training Loss on iteration 9 227.89539
# Current Training Loss on iteration 10 227.14832
# Current Training Loss on iteration 11 226.43114
# Current Training Loss on iteration 12 225.74234
# Current Training Loss on iteration 13 225.0808
# Current Training Loss on iteration 14 224.44553
# Current Training Loss on iteration 15 223.835
# Current Training Loss on iteration 16 223.24931
# Current Training Loss on iteration 17 222.68655
# Current Training Loss on iteration 18 222.14595
# Current Training Loss on iteration 19 221.62688
# Current Training Loss on iteration 20 221.12842
# Current Training Loss on iteration 21 220.6498
# Current Training Loss on iteration 22 220.18993
# Current Training Loss on iteration 23 219.74841
# Current Training Loss on iteration 24 219.32425
# Current Training Loss on iteration 25 218.91705
# Current Training Loss on iteration 26 218.52579
# Current Training Loss on iteration 27 218.15027
# Current Training Loss on iteration 28 217.78957
# Current Training Loss on iteration 29 217.44315
# Current Training Loss on iteration 30 217.11034
# Current Training Loss on iteration 31 216.79077
# Current Training Loss on iteration 32 216.48412
# Current Training Loss on iteration 33 216.18932
# Current Training Loss on iteration 34 215.90611
# Current Training Loss on iteration 35 215.63437
# Current Training Loss on iteration 36 215.37334
# Current Training Loss on iteration 37 215.12263
# Current Training Loss on iteration 38 214.88185
# Current Training Loss on iteration 39 214.65053
# Current Training Loss on iteration 40 214.42859
# Current Training Loss on iteration 41 214.21527
# Current Training Loss on iteration 42 214.01044
# Current Training Loss on iteration 43 213.81369
# Current Training Loss on iteration 44 213.62482
# Current Training Loss on iteration 45 213.44333
# Current Training Loss on iteration 46 213.2691
# Current Training Loss on iteration 47 213.10179
# Current Training Loss on iteration 48 212.94106
# Current Training Loss on iteration 49 212.78687
# Current Training Loss on iteration 50 212.63857
# Current Training Loss on iteration 51 212.4961
# Current Training Loss on iteration 52 212.35948
# Current Training Loss on iteration 53 212.22816
# Current Training Loss on iteration 54 212.10205
# Current Training Loss on iteration 55 211.98093
# Current Training Loss on iteration 56 211.86461
# Current Training Loss on iteration 57 211.75293
# Current Training Loss on iteration 58 211.64558
# Current Training Loss on iteration 59 211.54266
# Current Training Loss on iteration 60 211.44374
# Current Training Loss on iteration 61 211.34874
# Current Training Loss on iteration 62 211.2575
# Current Training Loss on iteration 63 211.16982
# Current Training Loss on iteration 64 211.08572
# Current Training Loss on iteration 65 211.00484
# Current Training Loss on iteration 66 210.92729
# Current Training Loss on iteration 67 210.85278
# Current Training Loss on iteration 68 210.78104
# Current Training Loss on iteration 69 210.71225
# Current Training Loss on iteration 70 210.64633
# Current Training Loss on iteration 71 210.58289
# Current Training Loss on iteration 72 210.52199
# Current Training Loss on iteration 73 210.46347
# Current Training Loss on iteration 74 210.4073
# Current Training Loss on iteration 75 210.3533
# Current Training Loss on iteration 76 210.30153
# Current Training Loss on iteration 77 210.2518
# Current Training Loss on iteration 78 210.204
# Current Training Loss on iteration 79 210.15811
# Current Training Loss on iteration 80 210.1141
# Current Training Loss on iteration 81 210.0717
# Current Training Loss on iteration 82 210.03108
# Current Training Loss on iteration 83 209.99205
# Current Training Loss on iteration 84 209.95453
# Current Training Loss on iteration 85 209.91852
# Current Training Loss on iteration 86 209.88396
# Current Training Loss on iteration 87 209.85075
# Current Training Loss on iteration 88 209.81891
# Current Training Loss on iteration 89 209.78818
# Current Training Loss on iteration 90 209.75874
# Current Training Loss on iteration 91 209.73053
# Current Training Loss on iteration 92 209.70349
# Current Training Loss on iteration 93 209.67744
# Current Training Loss on iteration 94 209.65225
# Current Training Loss on iteration 95 209.62833
# Current Training Loss on iteration 96 209.6052
# Current Training Loss on iteration 97 209.58302
# Current Training Loss on iteration 98 209.56174
# Current Training Loss on iteration 99 209.5413

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
W.numpy()
# Out:
# array([[0.0547828 ],
#        [0.05488191],
#        [0.05422735],
#        [0.05533117]], dtype=float32)

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
b.numpy()
# Out:
# array([4.607657], dtype=float32)
